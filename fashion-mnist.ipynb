# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import matplotlib.pyplot as plt
a = 36
print(class_names[y_train[a]])
plt.figure()
plt.imshow(x_train[a])
plt.show()
# Out:
# Sandal

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense ,Flatten

# %%
model = Sequential()

model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10,batch_size=32)

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test=x_test.reshape(-1,28,28,1)

# %%
from tensorflow.keras.utils import to_categorical
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

# %%
from tensorflow.keras.layers import Conv2D,MaxPool2D

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(MaxPool2D(2,2))

model.add(Conv2D(64,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(MaxPool2D(2,2))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 71s 37ms/step - loss: 0.5785 - accuracy: 0.8181 - val_loss: 0.3836 - val_accuracy: 0.8648
# Epoch 2/10
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.3400 - accuracy: 0.8752 - val_loss: 0.3390 - val_accuracy: 0.8730
# Epoch 3/10
# 1875/1875 [==============================] - 72s 38ms/step - loss: 0.2973 - accuracy: 0.8910 - val_loss: 0.3488 - val_accuracy: 0.8732
# Epoch 4/10
# 1875/1875 [==============================] - 78s 42ms/step - loss: 0.2743 - accuracy: 0.8982 - val_loss: 0.3069 - val_accuracy: 0.8912
# Epoch 5/10
# 1875/1875 [==============================] - 77s 41ms/step - loss: 0.2538 - accuracy: 0.9050 - val_loss: 0.3070 - val_accuracy: 0.8898
# Epoch 6/10
# 1875/1875 [==============================] - 68s 36ms/step - loss: 0.2354 - accuracy: 0.9119 - val_loss: 0.3154 - val_accuracy: 0.8908
# Epoch 7/10
# 1875/1875 [==============================] - 67s 36ms/step - loss: 0.2239 - accuracy: 0.9169 - val_loss: 0.3085 - val_accuracy: 0.8935
# Epoch 8/10
# 1875/1875 [==============================] - 65s 35ms/step - loss: 0.2072 - accuracy: 0.9230 - val_loss: 0.3090 - val_accuracy: 0.8938
# Epoch 9/10
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.1972 - accuracy: 0.9260 - val_loss: 0.3165 - val_accuracy: 0.8918
# Epoch 10/10
# 1875/1875 [==============================] - 70s 37ms/step - loss: 0.1871 - accuracy: 0.9290 - val_loss: 0.3227 - val_accuracy: 0.8960
